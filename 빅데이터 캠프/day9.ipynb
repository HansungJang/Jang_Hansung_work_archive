# %%
#.agg() : 함수 review
import pandas as pd

data = {
    '그룹': ['A', 'A', 'B', 'B', 'A', 'B', 'A'],
    '값': [10, 15, 20, 25, 30, 35, 40]
}

df = pd.DataFrame(data)

result = df.groupby('그룹').agg(평균값=('값', 'mean'), 합계=('값', 'sum'))
print(result)
# Out:
#           평균값  합계
# 그룹
# A   23.750000  95
# B   26.666667  80

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#execel 파일 가져오기; 
import os
#os.getcwd() 현재 패쓰 확인 
os.chdir('C:\\Users\\jangs\\archive\\')
accident = pd.read_excel('traffic_accident.xlsx')
accident
# Out:
#    자치구별        항목 2019. 01 2019. 02 2019. 03 2019. 04 2019. 05 2019. 06  \
# 0    소계  발생건수 (건)     2983     2482     3099     3283     3497     3290
# 1   NaN  사망자수 (명)       25       13       22       14       24       20
# 2   NaN  부상자수 (명)     4134     3368     4223     4500     4886     4542
# 3   종로구  발생건수 (건)       87       66       87       85      112       95
# 4   NaN  사망자수 (명)        1        1        2        -        1        1
# ..  ...       ...      ...      ...      ...      ...      ...      ...
# 73  NaN  사망자수 (명)        -        2        -        -        3        -
# 74  NaN  부상자수 (명)      319      253      336      317      398      311
# 75  강동구  발생건수 (건)       98       87      122      112      139      123
# 76  NaN  사망자수 (명)        1        -        -        -        1        1
# 77  NaN  부상자수 (명)      115      133      163      153      192      179
#
#    2019. 07 2019. 08 2019. 09 2019. 10 2019. 11 2019. 12
# ...

# %%
#중구의 월별 교통사고 발생건수 막대그래프로 확인 
accident.dtypes
# Out:
# 자치구별        object
# 항목          object
# 2019. 01    object
# 2019. 02    object
# 2019. 03    object
# 2019. 04    object
# 2019. 05    object
# 2019. 06    object
# 2019. 07    object
# 2019. 08    object
# 2019. 09    object
# 2019. 10    object
# 2019. 11    object
# 2019. 12    object
# dtype: object

# %%
#accident[['항목','2019. 01']] # 원하는 column 선택 
#accident.drop('자치구별', axis=1) #원하는 행을 삭제할때 (필요없는 변수 제거)
#데이터 사용할때는 변수 저장이후 사용이 가능; 
accident.shape
# Out:
# (78, 14)

# %%
#중구 지역 월별 교통사고 발생 건수 선그래프
#자치구 이름 데이터 반복작업으로 
for i in range(0,78-2,3):
    accident['자치구별'][i+1] = accident['자치구별'][i]
    accident['자치구별'][i+2] = accident['자치구별'][i]

# %%
accident
# Out:
#    자치구별        항목 2019. 01 2019. 02 2019. 03 2019. 04 2019. 05 2019. 06  \
# 0    소계  발생건수 (건)     2983     2482     3099     3283     3497     3290
# 1    소계  사망자수 (명)       25       13       22       14       24       20
# 2    소계  부상자수 (명)     4134     3368     4223     4500     4886     4542
# 3   종로구  발생건수 (건)       87       66       87       85      112       95
# 4   종로구  사망자수 (명)        1        1        2        -        1        1
# ..  ...       ...      ...      ...      ...      ...      ...      ...
# 73  송파구  사망자수 (명)        -        2        -        -        3        -
# 74  송파구  부상자수 (명)      319      253      336      317      398      311
# 75  강동구  발생건수 (건)       98       87      122      112      139      123
# 76  강동구  사망자수 (명)        1        -        -        -        1        1
# 77  강동구  부상자수 (명)      115      133      163      153      192      179
#
#    2019. 07 2019. 08 2019. 09 2019. 10 2019. 11 2019. 12
# ...

# %%
from matplotlib import font_manager, rc
#font_manager.FontProperties
#font_name =font_manager.FontProperties()
#(fname='C:\Windows\Fonts\HancomEQN.ttf').get_name()
#rc('font', family=HancomEQN.ttf)

# 모든 폰트 리스트를 가져옵니다.
font_list = font_manager.findSystemFonts(fontpaths=None, fontext='ttf')

# 한글이 포함된 폰트를 출력합니다.
for font_path in font_list:
    font_prop = font_manager.FontProperties(fname=font_path)
    if 'HY' in font_prop.get_name():
        print(font_prop.get_name(), font_path)
# Out:
# HYPMokGak-Bold C:\Windows\Fonts\H2MKPB.TTF
# HYPost-Medium C:\Windows\Fonts\H2PORM.TTF
# HYGothic-Medium C:\Windows\Fonts\H2GTRM.TTF
# HYMyeongJo-Extra C:\Windows\Fonts\H2MJRE.TTF
# HYGraphic-Medium C:\Windows\Fonts\H2GPRM.TTF
# HYShortSamul-Medium C:\Windows\Fonts\H2SA1M.TTF
# HYHeadLine-Medium C:\Windows\Fonts\H2HDRM.TTF
# HYGothic-Extra C:\Windows\Fonts\H2GTRE.TTF
# HYPost-Light C:\Windows\Fonts\H2PORL.TTF
# HYGungSo-Bold C:\Windows\Fonts\H2GSRB.TTF
# HYSinMyeongJo-Medium C:\Windows\Fonts\H2MJSM.TTF

# %%
#한글 폰트 import
font_name =font_manager.FontProperties(fname="C:\Windows\Fonts\H2MKPB.TTF").get_name()
rc('font', family=font_name)

# %%
#필터링 (특정컬럼, 해당데이터 추출)
accident[accident.자치구별 == '중구']
accident[accident.자치구별 == '중구'][accident.항목 == '발생건수 (건)']
jg = accident[accident.자치구별 == '중구'][accident.항목 == '발생건수 (건)'].iloc[:,2:] #dataframe이여서 전체row에서 colum지정


import calendar
#calendar.month_name[1:13]
plt.plot(calendar.month_name[1:13],jg.values.flatten()) #flatten함수; 2차원 배열 -> 1차원 배열로 만듬
#2번째: jg.values[0][1:13] 값에 해당부분을  직접 가지고 와서 추출
plt.grid()
plt.xlabel('월')
plt.ylabel('발생 건수')
plt.title('중구 교통사고 발생건수')
plt.xticks( rotation=20)
plt.show()
# Out:
# C:\Users\jangs\AppData\Local\Temp\ipykernel_16208\373060262.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   accident[accident.자치구별 == '중구'][accident.항목 == '발생건수 (건)']
# C:\Users\jangs\AppData\Local\Temp\ipykernel_16208\373060262.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   jg = accident[accident.자치구별 == '중구'][accident.항목 == '발생건수 (건)'].iloc[:,2:] #dataframe이여서 전체row에서 colum지정

# %%
#plot 그래프

#데이터 추출의 예
#1. data frame으로 
#발생건수 = accident[accident['자치구별']=='소계'][accident.항목 == '발생건수 (건)'].iloc[:, 2:]
#사망자수 = accident[accident['자치구별']=='소계'][accident.항목 == '사망건수 (건)'].iloc[:, 2:]
#부상자수 = accident[accident['자치구별']=='소계'][accident.항목 == '부상건수 (건)'].iloc[:, 2:]

발생건수 = accident.iloc[0][2:]
사망자수 = accident.iloc[1][2:]
부상자수 = accident.iloc[2][2:]

plt.plot(발생건수, 'g>')
plt.plot(사망자수, 'b-')
plt.plot(부상자수, 'r-')
plt.legend(['발생건수','사망건수','부상건수'])
plt.xticks(np.arange(12), [str(i)+'월' for i in range(1,13)], rotation=20)
plt.show()

# %%
#bar 12월 지역별 사망자수 
decm = accident[1:][accident.항목 == '사망자수 (명)'][['자치구별','2019. 12']]
decm
decm.columns = ['region', 'dec'] #column 이름 변경
decm.dec.replace('-','0',inplace=True) #null => 0 대입
decm
decm.dec = decm.dec.astype('int') #자료형 변환
decm.dtypes
plt.bar(decm.region, decm.dec)
plt.xticks(rotation=60) #x축 글씨 회전
plt.title('12월 지역별 교통사고 사망자수')
plt.xlabel('지역')
plt.ylabel('사망자수 (명)')
plt.show()
# Out:
# C:\Users\jangs\AppData\Local\Temp\ipykernel_16208\4024193314.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   decm = accident[1:][accident.항목 == '사망자수 (명)'][['자치구별','2019. 12']]

# %%
df2 = pd.read_excel('2009-2019_monthly_accident.xlsx')
df2.shape
# Out:
# C:\anaconda\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# (78, 135)

# %%
df2
# Out:
#    자치구별(1) 자치구별(2)        항목 2009. 01 2009. 02 2009. 03 2009. 04 2009. 05  \
# 0       합계      소계  발생건수 (건)     3111     3073     3578     3576     3814
# 1      NaN     NaN  사망자수 (명)       52       47       41       34       44
# 2      NaN     NaN  부상자수 (명)     4839     4531     5132     5047     5424
# 3      NaN     종로구  발생건수 (건)      100      107      124      123      134
# 4      NaN     NaN  사망자수 (명)        4        1        -        1        1
# ..     ...     ...       ...      ...      ...      ...      ...      ...
# 73     NaN     NaN  사망자수 (명)        2        1        1        1        2
# 74     NaN     NaN  부상자수 (명)      327      305      382      342      340
# 75     NaN     강동구  발생건수 (건)      120      118      149      120      137
# 76     NaN     NaN  사망자수 (명)        4        -        1        2        3
# 77     NaN     NaN  부상자수 (명)      169      157      202      170      181
#
#    2009. 06 2009. 07  ... 2019. 03 2019. 04 2019. 05 2019. 06 2019. 07  \
# ...

# %%
# 같은 자치구 빈칸 채우기
for i in range(0,78-2,3):
    df2['자치구별(2)'][i+1] = df2['자치구별(2)'][i]
    df2['자치구별(2)'][i+2] = df2['자치구별(2)'][i]

# %%
#df2 = df2.drop('자치구별(1)', axis=1) #특정 컬럼 제거
df2.columns
# Out:
# Index(['자치구별(1)', '자치구별(2)', '항목', '2009. 01', '2009. 02', '2009. 03',
#        '2009. 04', '2009. 05', '2009. 06', '2009. 07',
#        ...
#        '2019. 03', '2019. 04', '2019. 05', '2019. 06', '2019. 07', '2019. 08',
#        '2019. 09', '2019. 10', '2019. 11', '2019. 12'],
#       dtype='object', length=135)

# %%
#scatter (x: 교통사고 발생건수, y:부상자)
#연도별로 사고 발생 category 합 / 부상자 합
#happen = df2[0:][df2.항목 == '발생건수 (건)'][['자치구별','2019. 12']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[122], line 3
#       1 #scatter (x: 교통사고 발생건수, y:부상자)
#       2 #연도별로 사고 발생 category 합 / 부상자 합
# ----> 3 happen = df2[['항목 == 발생건수 (건)']]
#
# File C:\anaconda\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File C:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
# ...

# %%
df2 
#원하는 값은 월별 데이터이므로 해당 부분만 가져오는 것 step1
df2 = df2.iloc[:, 3:].apply(lambda x: x.replace('-','0').astype('int')) #추출한 데이터에 대해서 null부분 0, 자료형 (str >> int) 함수 적용 step2
df2.dtypes
# Out:
# 2009. 01    int32
# 2009. 02    int32
# 2009. 03    int32
# 2009. 04    int32
# 2009. 05    int32
#             ...
# 2019. 08    int32
# 2019. 09    int32
# 2019. 10    int32
# 2019. 11    int32
# 2019. 12    int32
# Length: 132, dtype: object

# %%
df2
# Out:
#     2009. 01  2009. 02  2009. 03  2009. 04  2009. 05  2009. 06  2009. 07  \
# 0       3111      3073      3578      3576      3814      3732      4037
# 1         52        47        41        34        44        38        33
# 2       4839      4531      5132      5047      5424      5214      5776
# 3        100       107       124       123       134       128       152
# 4          4         1         0         1         1         2         1
# ..       ...       ...       ...       ...       ...       ...       ...
# 73         2         1         1         1         2         2         3
# 74       327       305       382       342       340       357       308
# 75       120       118       149       120       137       107       147
# 76         4         0         1         2         3         3         3
# 77       169       157       202       170       181       152       201
#
#     2009. 08  2009. 09  2009. 10  ...  2019. 03  2019. 04  2019. 05  2019. 06  \
# ...

# %%
발생건수 = df2.iloc[0]  #계수 : 해당 연도 총합.. :)
부상자수 = df2.iloc[2]
발생건수
# Out:
# 2009. 01    3111
# 2009. 02    3073
# 2009. 03    3578
# 2009. 04    3576
# 2009. 05    3814
#             ...
# 2019. 08    3447
# 2019. 09    3313
# 2019. 10    3634
# 2019. 11    3669
# 2019. 12    3250
# Name: 0, Length: 132, dtype: int32

# %%
plt.figure(figsize=(5,5))
plt.scatter(발생건수, 부상자수)
plt.xlabel('발생건수')
plt.ylabel('부상자수')
plt.xlim(0,5000) #범위 확장
#plt.ylim(0,6000)
plt.title('2009년~2019년\n교통사고 발생 건수와 부상자수의 산점도')
plt.show()

# %%
#사고 발생건수 (행 간격:3) start:0 end:75
#부상자 발생건수 (행 간격:3) start: 2 end:77

#행 별로 데이터 합치기 위해서는 
example_sum = 0 #2009.01 사고 발생건수 
for i in range(0,76,3):
    example_sum += df2['2009. 01'][i]
example_sum
# Out:
# 6222

# %%
#heat-map
plt.pcolor(np.corrcoef(발생건수, 부상자수))
plt.colorbar()
plt.show()

# %%
#결측치 처리

# %%
#null값의 데이터 처리
a = np.array([1, np.nan, 3, 4])
a.dtype
# Out:
# dtype('float64')

# %%
#null 있으면 계산이 안됨
np.nan +1
np.nan*1
a.sum()
a.mean()
# Out:
# nan

# %%
# null 값이 있는 series에서  계산이 가능하게 되는 방법
np.nansum(a) #합
np.nanmin(a) #최소
np.nanmax(a) #최대
# Out:
# 4.0

# %%
#널 값의 표현 방법 
#lst = np.array([np.nan, None])
lst = [np.nan, None]
pd.Series(lst)
# Out:
# 0   NaN
# 1   NaN
# dtype: float64

# %%
#데이터에 null 찾기 
lst = [1, np.nan, 'hello', None]
s = pd.Series(lst)
s.isnull() #null = true / s.isna() : 같은 명령어 
s.notnull() #null = false / s['s.notnull()']

s.isna().sum() #널 값의 갯수를 출력
# Out:
# 2

# %%
# 2차원 데이터에 대하여 NULL값을 찾을때 
a =[[1, np.nan, 2],[1, 2, 3],[np.nan,1,2]]
df = pd.DataFrame(a) 
df.columns = list('abc')
df.isna().sum() # 컬럼별로 널값의 갯수를 셈
# Out:
# a    1
# b    1
# c    0
# dtype: int64

# %%
#row 기준 , NULL값이 1개라도 있다면 행을 제거 
df.dropna()
# Out:
#      a    b  c
# 1  1.0  2.0  3

# %%
#column을 기준으로 할때, axis=1 사용
df.dropna(axis=1)
# Out:
#    c
# 0  2
# 1  3
# 2  2

# %%
df
# Out:
#      a    b  c
# 0  1.0  NaN  2
# 1  1.0  2.0  3
# 2  NaN  1.0  2

# %%
#저장하기 위해서는 implace=True , or 초기화
a =[[1, np.nan, 2],[1, 2, 3],[np.nan,1,2],[np.nan, np.nan, np.nan]]
df = pd.DataFrame(a)
df.columns = list('123')
df.dropna(how='all') #전체가 널 값인 행만 제거 
#df.iloc[3] = [np.nan, np.nan, np.nan]
# Out:
#      1    2    3
# 0  1.0  NaN  2.0
# 1  1.0  2.0  3.0
# 2  NaN  1.0  2.0

# %%
df.dropna(thresh=3) #널 값이 아닌 값이 적어도 3개 이상인 것만 남김 
df.dropna(how='all', inplace=True)
df.fillna(0) #null값에 0대입
# Out:
#      1    2    3
# 0  1.0  0.0  2.0
# 1  1.0  2.0  3.0
# 2  0.0  1.0  2.0

# %%
df.a.fillna(df.a.mean()) #mean_value fill
df.a.fillna(df.a.median()) #치우친 데이터인 경우 / 중윗수를 대입

# %%
import random
import string #문자열
df = pd.DataFrame({  # dataframe에 저장하지 않으면 df 이용불가!
    'temperature': random.sample(list(np.arange(40)),10), #sequence 값이 아니라고 error
    'windspeed': random.sample(list(np.arange(20)),10),
    'event': random.sample(string.ascii_letters, 10) #임의 문자열 
    #string.src
})

# 해당 원소에 null값을 넣음
df.loc[3,'temperature'] = np.nan 
df.loc[1,'windspeed'] = np.nan
df.loc[8,'event'] = np.nan

# %%
df
# Out:
#    temperature  windspeed event
# 0         14.0       16.0     k
# 1         12.0        NaN     G
# 2          5.0        9.0     g
# 3          NaN        7.0     T
# 4          2.0       19.0     H
# 5          6.0        1.0     N
# 6         22.0        0.0     u
# 7         11.0        3.0     V
# 8         31.0        5.0   NaN
# 9         16.0       10.0     p

# %%
df = df.fillna({'temperature' :0, 
               'windspeed': 0,
               'event': 'no_event'}, inplace=True) #column에서 널 값인 값을 대체
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[189], line 1
# ----> 1 df = df.fillna({'temperature' :0,
#       2                'windspeed': 0,
#       3                'event': 'no_event'}, inplace=True) #column에서 널 값인 값을 대체
#       4 df
#
# AttributeError: 'NoneType' object has no attribute 'fillna'

# %%
df3 = pd.read_excel('2009-2019_monthly_accident.xlsx')
data = df3.iloc[0][3:]

len(data)
data
# Out:
# C:\anaconda\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 2009. 01    3111
# 2009. 02    3073
# 2009. 03    3578
# 2009. 04    3576
# 2009. 05    3814
#             ...
# 2019. 08    3447
# 2019. 09    3313
# 2019. 10    3634
# 2019. 11    3669
# 2019. 12    3250
# Name: 0, Length: 132, dtype: object

# %%
#시계열 데이터에 널 값을 데입하여 처리
df3 = pd.read_excel('2009-2019_monthly_accident.xlsx')
data = df3.iloc[0][3:]

#직접 지정 
#data['2009. 01'] = np.nan
#data['2010. 04'] = np.nan
#data['2019. 08'] = np.nan

#random 으로 지정
data = df3.iloc[0][3:].values
len(data) 
for i in range(3):#3군데 널값 만들기
    rnum = random.randint(0,132)
    data[rnum:rnum+3+i] = np.nan
    
data1 = data.copy()
data1
data
# Out:
# C:\anaconda\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# array([3111, 3073, 3578, 3576, 3814, 3732, 4037, 3669, 4079, 4115, 3705,
#        3831, 3109, 2948, 3388, 3510, 3721, 3507, 3535, 3558, 3580, 3930,
#        3555, 3321, 3038, 2573, 3126, 3450, 3603, 3390, 3529, 3360, 3433,
#        3734, 3701, 3514, 2990, 3069, 3356, 3451, 3605, 3555, 3581, 3405,
#        3480, 3456, 3621, 3260, 3005, 2562, 3311, 3361, 3643, 3540, 3304,
#        nan, nan, nan, nan, nan, 2687, 2566, 3335, 3316, 3628, 3576, 3752,
#        3544, 3482, 3698, 3656, 3552, 2967, 2682, 3384, 3506, 3669, 3390,
#        3647, 3567, 3711, 3820, 3794, 3528, 3060, 2710, 3355, 3498, 3604,
#        3315, 3467, 3268, 3328, 3652, 3331, 3451, 3166, 2728, 3098, 3172,
#        3284, 3247, 3268, 3308, 3488, 3312, 3375, 3179, 3192, 2973, 3072,
# ...

# %%
#시계열 데이터의 시각화 
plt.plot(data1) 
plt.show()

# %%
pd.DataFrame(data1).fillna(method='ffill').plot() #연속되는 데이터 빈칸의 값 채우기 위한 방법으로 : ffill:forward 앞의 값을 넣는 것
# Out:
# <Axes: >

# %%
#pd.DataFrame(data1).fillna(method='pad').plot() #pad마찬가지  
pd.DataFrame(data1).fillna(method='bfill',limit=1).plot() #backfill(혹은 bfill: 뒤에 갚을 채우는 경우)
#채워지는 값을 제한
# Out:
# <Axes: >

# %%
df= pd.DataFrame([[1, np.nan , 2], [2, 3, 5], [np.nan ,4, 6]])
df
df.fillna(method='ffill', axis=1) #방향을 행방향으로 바꿈(defaault는 열, 위에서 아래)
# Out:
#      0    1    2
# 0  1.0  1.0  2.0
# 1  2.0  3.0  5.0
# 2  NaN  4.0  6.0

# %%
pd.DataFrame(data1).dtypes
# Out:
# 0    object
# dtype: object

# %%
#interpolate 으로 채움 >> 시계열 데이터를 이용할때 사용하는 method; 예측치로 그래프를 그림(단, 데이터가 '계량','수치화'데이터로 바꿔야함.  가능해야함.)
pd.DataFrame(data1.astype('float')).interpolate().plot() #'.plot()' 바로 해당 데이터에 대해서 막대 그래프가 생성
# Out:
# <Axes: >

# %%
food = pd.read_csv('en.openfoodfacts.org.products.tsv', delimiter='\t') #파일 토큰나이즈 error가 발생하였을때 해결방법
# Out:
# C:\Users\jangs\AppData\Local\Temp\ipykernel_27724\2185840399.py:1: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   food = pd.read_csv('en.openfoodfacts.org.products.tsv', delimiter='\t') #파일 토큰나이즈 error가 발생하였을때 해결방법

# %%
food
# Out:
#                  code                                                url  \
# 0                3087  http://world-en.openfoodfacts.org/product/0000...
# 1                4530  http://world-en.openfoodfacts.org/product/0000...
# 2                4559  http://world-en.openfoodfacts.org/product/0000...
# 3               16087  http://world-en.openfoodfacts.org/product/0000...
# 4               16094  http://world-en.openfoodfacts.org/product/0000...
# ...               ...                                                ...
# 356022       99567453  http://world-en.openfoodfacts.org/product/9956...
# 356023  9970229501521  http://world-en.openfoodfacts.org/product/9970...
# 356024  9977471758307  http://world-en.openfoodfacts.org/product/9977...
# 356025  9980282863788  http://world-en.openfoodfacts.org/product/9980...
# 356026   999990026839  http://world-en.openfoodfacts.org/product/9999...
#
#                            creator   created_t      created_datetime  \
# ...

# %%
#food file에 null값을 확인하는 방법
food.isna()
# plt.pcolor(food.isna()) #heat-map: matrix 데이터를 시각화할때 유용
# Out:
#          code    url  creator  created_t  created_datetime  last_modified_t  \
# 0       False  False    False      False             False            False
# 1       False  False    False      False             False            False
# 2       False  False    False      False             False            False
# 3       False  False    False      False             False            False
# 4       False  False    False      False             False            False
# ...       ...    ...      ...        ...               ...              ...
# 356022  False  False    False      False             False            False
# 356023  False  False    False      False             False            False
# 356024  False  False    False      False             False            False
# 356025  False  False    False      False             False            False
# 356026  False  False    False      False             False            False
#
# ...

# %%
# !pip install missingno
import missingno as msno

# %%
msno.matrix(food) #하얀 부분이 null값을 표현 msno.bar(food), msno.heatmap(food) 같은 것으로도 시각화 가능
# Out:
# <Axes: >

# %%
food.isna().sum() #컬럼별로 null값 갯수를 확인
# Out:
# code                           26
# url                            26
# creator                         3
# created_t                       3
# created_datetime               10
#                             ...
# carbon-footprint_100g      355749
# nutrition-score-fr_100g    101171
# nutrition-score-uk_100g    101171
# glycemic-index_100g        356027
# water-hardness_100g        356027
# Length: 163, dtype: int64

# %%
food.isna().sum().sum() #데이터 전체에 있는 null값의 갯수를 확인
# Out:
# 44183489

# %%
food.dtypes
# Out:
# code                        object
# url                         object
# creator                     object
# created_t                   object
# created_datetime            object
#                             ...
# carbon-footprint_100g      float64
# nutrition-score-fr_100g    float64
# nutrition-score-uk_100g    float64
# glycemic-index_100g        float64
# water-hardness_100g        float64
# Length: 163, dtype: object

# %%
food.shape
# Out:
# (356027, 163)

# %%
food1 = food.dropna() #null이 1개 라도있으면 제거 
food1.shape
# Out:
# (0, 163)

# %%
#전체가 null인 값만 제거 
food2 = food.dropna(how='all')
food2.shape
# Out:
# (356027, 163)

# %%
#column 방향으로 제거할때 
food3 = food.dropna(how='all',axis=1)
food3.shape
# Out:
# (356027, 147)

# %%
#coloum별로 평균값을 데입 (실무에서는 type 고려하여 대입 )
food4 = food.iloc[:100, :100]

food4 = food4.dropna(how='all',axis=1)
food4.shape
food4 = food4.fillna(food4.mean()) # colum기준 평균값을 대입
food4.isna().sum()

food5 = food4.dropna(how='all',axis=1)
food5
# Out:
# C:\Users\jangs\AppData\Local\Temp\ipykernel_27724\1613622795.py:6: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   food4 = food4.fillna(food4.mean()) # colum기준 평균값을 대입
#      code                                                url  \
# 0    3087  http://world-en.openfoodfacts.org/product/0000...
# 1    4530  http://world-en.openfoodfacts.org/product/0000...
# 2    4559  http://world-en.openfoodfacts.org/product/0000...
# 3   16087  http://world-en.openfoodfacts.org/product/0000...
# 4   16094  http://world-en.openfoodfacts.org/product/0000...
# ..    ...                                                ...
# 95  34715  http://world-en.openfoodfacts.org/product/0000...
# 96  34784  http://world-en.openfoodfacts.org/product/0000...
# ...

# %%
2/3/5*3-10
# Out:
# -9.6

# %%
df = pd.DataFrame({'name':['john','mary, paul],'age':[30,25,40],'city':['newyork','los angeles', 'london']})

df.replace(25,30)
df.replace([30,40], np.nan
#패턴으로 대체 
df.replace('[A-Za-a]','',regex=True, inplace=True)
#각각 매치되는 값을 리스트로 만들어 대체; 머신러닝에서 사용

# %%
left = pd.DataFrame ({ 'id':[1,2,3,4,5], 'Name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung '],'subject_id ':['sub1','sub2','sub4','sub6','sub5']})
right =pd.DataFrame ( {'id':[1,2,3,4,5],'Name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
'subject_id ':['sub2','sub4','sub3','sub6','sub5']})

left
# Out:
#    id     Name subject_id
# 0   1     Alex        sub1
# 1   2      Amy        sub2
# 2   3    Allen        sub4
# 3   4    Alice        sub6
# 4   5  Ayoung         sub5

# %%
right
# Out:
#    id   Name subject_id
# 0   1  Billy        sub2
# 1   2  Brian        sub4
# 2   3   Bran        sub3
# 3   4  Bryce        sub6
# 4   5  Betty        sub5

# %%
pd.merge(left, right, on='subject_id', how='left')
#pd.merge(left, right, on='subject_id', how='right')
#pd.merge(left, right, on='subject_id', how='outer')
#pd.merge(left, right, on='subject_id', how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 pd.merge(left, right, on='subject_id', how='left')
#
# File C:\anaconda\Lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
# ...

# %%
#concat 위아래로 붙이기 (옆으로 붙이는 경우 axis=1)

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame ([[4, 9],] * 3, columns=['A','B'])
#df
#df.apply(np.sqrt)
#df.apply(np.sum)# 열로 적용
df.apply(np.sum, axis=1) # 행으로 적용
# Out:
# 0    13
# 1    13
# 2    13
# dtype: int64

# %%
def myfunc (n):
    return len (n)

x = map( myfunc , ('appleqq', 'banana', 'cherry'))
#type(x)
list(x)
# Out:
# [7, 6, 6]

# %%
tee = [[1,1],[2,2],[3,3] ]
len(tee)
# Out:
# 3

# %%
x = pd.Series ([1,2,3], index=['one', 'two','three'])
print(x)
y = pd.Series (['foo', 'bar', 'baz'],index=[1,2,3])
print(y)
z = {1: 'A', 2: 'B', 3: 'C'}
print(z)
print(x.map(y))
print(x.map(z))
# Out:
# one      1
# two      2
# three    3
# dtype: int64
# 1    foo
# 2    bar
# 3    baz
# dtype: object
# {1: 'A', 3: 'B', 2: 'C'}
# one      foo
# two      bar
# three    baz
# dtype: object
# one      A
# two      C
# three    B
# dtype: object
